# %%
import pandas as pd

# %%
data = pd.read_csv("./EDA.csv")

# %%
data
# Out:
#              task  phase  total  positive
# 0           NR-AR  train   5812     241.0
# 1           NR-AR   test   1453      68.0
# 2       NR-AR-LBD  train   5406     192.0
# 3       NR-AR-LBD   test   1352      45.0
# 4          NR-AhR  train   5239     616.0
# 5          NR-AhR   test   1310     152.0
# 6    NR-Aromatase  train   4656     239.0
# 7    NR-Aromatase   test   1165      61.0
# 8           NR-ER  train   4954     636.0
# 9           NR-ER   test   1239     157.0
# 10      NR-ER-LBD  train   5564     268.0
# 11      NR-ER-LBD   test   1391      82.0
# 12  NR-PPAR-gamma  train   5160     150.0
# 13  NR-PPAR-gamma   test   1290      36.0
# 14         SR-ARE  train   4665     764.0
# 15         SR-ARE   test   1167     178.0
# 16       SR-ATAD5  train   5657     212.0
# 17       SR-ATAD5   test   1415      52.0
# 18         SR-HSE  train   5173     295.0
# 19         SR-HSE   test   1294      77.0
# 20         SR-MMP  train   4648     741.0
# ...

# %%
total_data = pd.read_csv("./Data/tox21.csv")

# %%
total_data.shape
# Out:
# (7831, 14)

# %%
7831-5812-1453
7831-5460-1352
# Out:
# 1019
